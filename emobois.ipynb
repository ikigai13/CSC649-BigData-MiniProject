# %%
# Testing & performance analysis -Testing data 
import sklearn.metrics as skm 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(9,9)) 
sns.heatmap(skm.confusion_matrix(y2, yPred2), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r'); 
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Testing: Accuracy Score: {0}'.format(skm.accuracy_score(y2, yPred2)) 
plt.title(all_sample_title, size = 15);

# %%
#B. Train-test dataset
# Read data from external file
import pandas as pd
dfCSV = pd.read_csv("C:/Users/nixon/Desktop/SMEP.csv")

dfCSV.head(2)
# Out:
#              Timestamp socmedInterest mostUsedSocmed Age  Gender occupation  \
# 0  11/23/2023 10:29:46            Yes         TikTok  18  Female    Student
# 1  11/23/2023 10:32:09            Yes         TikTok  21    Male    Student
#
#   monthlyIncome residence      device       internet  ...  socmedRate  \
# 0             0    hostel  Smartphone  Cellular Data  ...           3
# 1             0    hostel  Smartphone  Cellular Data  ...           3
#
#    picPost  vidPost  picLike  vidLike  comment  story  shareVid  \
# 0        5        5        5        5        3      5         5
# 1        1        1        3        3        4      2         5
#
#      watchVidAvg\n       interactionTime
# 0  More than 5 min  12:00 p.m - 6:00 p.m
# 1  Less than 5 min  6:00 p.m - 12:00 a.m
#
# [2 rows x 21 columns]

# %%
#Data transformation
from sklearn.preprocessing import LabelEncoder
var_mod = ['Timestamp', 'socmedInterest', 'mostUsedSocmed', 'Age', 'Gender', 'occupation', 'monthlyIncome', 'residence', 'device', 'internet', 'activeSocmed', 'socmedRate', 'picPost', 'vidPost', 'picLike', 'vidLike', 'comment', 'story',  'shareVid', 'watchVidAvg\n', 'interactionTime']
le = LabelEncoder()
for i in var_mod:
    dfCSV[i] = le.fit_transform(dfCSV[i])

# %%
#Create a dataset file (after imputation and transformation)
dfCSV.to_csv(r'C:/Users/nixon/Desktop/SMEPIT.csv', index = None, header=True)

# %%
# Read data from external file
import pandas as pd
dfCSV = pd.read_csv("C:/Users/nixon/Desktop/KF1_SMEP-Train.csv")

dfCSV.head()
# Out:
#    Timestamp  socmedInterest  mostUsedSocmed  Age  Gender  occupation  \
# 0        546               1              12   19       1           1
# 1        571               1              12   19       3           4
# 2        206               1              13   23       2           5
# 3        522               1               5   18       1           4
# 4        559               1              12   19       3           1
#
#    monthlyIncome  residence  device  internet  ...  socmedRate  picPost  \
# 0             22         46       3         3  ...           4        5
# 1              2         42       6         1  ...           2        2
# 2              2         55       7         1  ...           4        3
# 3              2         46       8         1  ...           5        4
# 4             38         42       6         3  ...           3        4
#
#    vidPost  picLike  vidLike  comment  story  shareVid  watchVidAvg\n  \
# ...

# %%
#To slice dataset for feature and target

X = dfCSV.iloc[:, 0:20]
y = dfCSV.iloc[:, 2:3]

# %%
# To split dataset 90-10, 80-20, 70-30, 60-40
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, shuffle=True)

# %%
# To combine features and its target 
train = pd.concat([X_train, y_train], axis=1, sort=False)
test = pd.concat([X_test, y_test], axis=1, sort=False)

# %%
# exporting the new dataset
train.to_csv(r'C:/Users/nixon/Desktop/SMEPIT-Train.csv', index = None, header=True)
test.to_csv(r'C:/Users/nixon/Desktop/SMEPIT-Test.csv', index = None, header=True)

# %%
# Read data from external file 
import pandas as pd 
dfCSV = pd.read_csv("C:/Users/nixon/Desktop/KF1_SMEP-Train.csv") 
 
 
# Data slicing 
x = dfCSV.iloc[:, 1:20]
y = dfCSV.iloc[:, [1]]
x.head() 


# Convert dataframe to array 
x = x.values 
y = y.values 
y = y.ravel() 
 

# K-Nearest Neighbor default
from sklearn.neighbors import KNeighborsClassifier 
Emobois_config1 = KNeighborsClassifier(n_neighbors=3, weights='uniform', algorithm='auto', leaf_size=30, p=1, metric='manhattan', metric_params=None, n_jobs=None)

Emobois.fit(x, y) 
yPred = Emobois.predict(x) 


# Testing & performance analysis -Trainning data 
import sklearn.metrics as skm 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(9,9)) 
sns.heatmap(skm.confusion_matrix(y, yPred), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r'); 
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Trainning: Accuracy Score: {0}'.format(skm.accuracy_score(y, yPred)) 
plt.title(all_sample_title, size = 15); 
  
# Read data from external file 
import pandas as pd 
dfCSV = pd.read_csv("C:/Users/nixon/Desktop/KF1_SMEP-TEST.csv") 
 
 
# Data slicing 
x2 = dfCSV.iloc[:, 1:20]
y2 = dfCSV.iloc[:, [1]]
x2.head() 


# Convert dataframe to array 
x2 = x2.values 
y2 = y2.values 
y2 = y2.ravel() 

yPred2 = Emobois.predict(x2) 
 
 
# Testing & performance analysis -Testing data 
import sklearn.metrics as skm 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(9,9)) 
sns.heatmap(skm.confusion_matrix(y2, yPred2), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r'); 
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Testing: Accuracy Score: {0}'.format(skm.accuracy_score(y2, yPred2)) 
plt.title(all_sample_title, size = 15);
